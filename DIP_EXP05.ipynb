# %% [markdown]
# #### Aim:- To study and perform non-linear neighborhood operations on images:   (A.)Min
#           (B.)Max
#           (C.)Median
#           (D.)With Various padding operations(zero, 1's, line,mirror)

# %%
## Min Filtering
### Import Important libraries
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt

##Read image using Pillow Library
img1=Image.open("/content/baboon.png")

## Resize image to 224x224
img1=img1.resize((224,224))

##Apply min filtering
new_image1=img1.filter(ImageFilter.MinFilter(size=3))

## Plot original image and min filtering image
fig=plt.figure(figsize=(6,4))
fig.add_subplot(1,2,1)
plt.imshow(img1)
plt.axis("off")
plt.title("Original Image")

fig.add_subplot(1,2,2)
plt.imshow(new_image1)
plt.axis("off")
plt.title("Min Filtered Image")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 import matplotlib.pyplot as plt
#       6 ##Read image using Pillow Library
# ----> 7 img1=Image.open("/content/baboon.png")
#       9 ## Resize image to 224x224
#      10 img1=img1.resize((224,224))
#
# File c:\Users\pashu\anaconda3\Lib\site-packages\PIL\Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
#    3514     exclusive_fp = True
#    3515 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/baboon.png'
