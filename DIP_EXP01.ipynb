# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\pashu\anaconda3\lib\site-packages (from opencv-python) (2.1.3)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.8/40.2 MB 8.7 MB/s eta 0:00:05
#    -- ------------------------------------- 2.4/40.2 MB 8.0 MB/s eta 0:00:05
#    --- ------------------------------------ 3.7/40.2 MB 8.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.8/40.2 MB 8.2 MB/s eta 0:00:05
#    ------- -------------------------------- 7.3/40.2 MB 8.0 MB/s eta 0:00:05
#    --------- ------------------------------ 9.2/40.2 MB 8.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 10.7/40.2 MB 8.1 MB/s eta 0:00:04
#    ------------ --------------------------- 12.6/40.2 MB 8.3 MB/s eta 0:00:04
#    -------------- ------------------------- 14.2/40.2 MB 8.2 MB/s eta 0:00:04
#    --------------- ------------------------ 15.7/40.2 MB 8.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.8/40.2 MB 8.3 MB/s eta 0:00:03
#    ------------------- -------------------- 19.7/40.2 MB 8.4 MB/s eta 0:00:03
#    --------------------- ------------------ 21.8/40.2 MB 8.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 23.9/40.2 MB 8.7 MB/s eta 0:00:02
#    ------------------------- -------------- 25.4/40.2 MB 8.8 MB/s eta 0:00:02
#    --------------------------- ------------ 27.5/40.2 MB 8.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 29.4/40.2 MB 8.8 MB/s eta 0:00:02
#    ------------------------------ --------- 30.9/40.2 MB 8.8 MB/s eta 0:00:02
#    -------------------------------- ------- 33.0/40.2 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 34.9/40.2 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 36.4/40.2 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 38.3/40.2 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  39.3/40.2 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 8.3 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('baboon.png')
plt.imshow(img1)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img1)
plt.axis("off")
plt.show()

# %%
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
plt.imshow(img1[:,:,::-1])
plt.axis('off')
plt.show()

# %%
img1.shape
H=255
W=255

##resizing of image
img4 = cv2.resize(img1, (100, 100))
img5 = cv2.resize(img1, (50, 50))

fig=plt.figure(figsize=(10,7))
fig.add_subplot(1,3,1)
plt.imshow(img1[:,:,::-1])
plt.axis("off")
plt.title('Original Image')

fig.add_subplot(1,3,2)
plt.imshow(img4)
plt.axis("off")
plt.title('Size=100x100')

fig.add_subplot(1,3,3)
plt.imshow(img5)
plt.axis("off")
plt.title('Size=50x50')

plt.show()
